# %% [markdown]
# # CC3001 2023-1 - Tarea 6: Quicksort
# # Nombre: Valentina Alarcón Y.
# Profesores: Iván Sipirán, Nelson Baloian, Patricio Poblete

# %% [markdown]
# En esta tarea, usted debe comparar el desempeño de la versión original de Quicksort con el de la variante "Mediana de 3". En la primera, el método de partición debe elegir el pivote como el primer elemento del sub arreglo que está particionando. En la segunda, el pivote debe elegirse como la mediana entre el primero, el del medio y el último elemento. Usted debe entregar un link a su tarea en `colab`.

# %% [markdown]
# ---
# # Quicksort original

# %% [markdown]
# La versión que se vio en cátedra de Quicksort elige el pivote como un elemento escogido al azar de entre los del arreglo. Para esta tarea vamos a elegir el pivote como el primer elemento del subarreglo para evitar usar la función random.randint() de python que puede ser muy lenta. Dado que para esta tarea los arreglos a ordenar se generarán de manera aleatoria, el primer elemento de la serie se puede ver como un elemento escogido al azar. Sin embargo, esta no es una práctica recomendable en la realidad, ya que si el arreglo viene ordenado, esto llevará a que se tenga el peor caso de Quicksort. La implementación que usaremos de Quicksort es la siguiente:

# %%
# Para el item de comparaciones, crearemos dos variables globales que almacenen la cantidad buscada
# De acuerdo al método utilizado
contador_qs = 0
contador_qs3 = 0

def quicksort(a):
    qsort(a,0,len(a)-1)

def qsort(a,i,j): # ordena a[i],...,a[j]
    if i<j: # quedan 2 o más elementos por ordenar
        k=particion(a,i,j)
        qsort(a,i,k-1)
        qsort(a,k+1,j)


def particion(a,i,j): # particiona a[i],...,a[j], retorna posición del pivote
    # a[i] es el pivote
    # para contar las comparaciones:
    s=i # invariante: a[i+1..s]<=a[i], a[s+1..t]>a[i]
    global contador_qs
    for t in range(s,j):
        contador_qs += 1
        if a[t+1]<=a[i]:
            (a[s+1],a[t+1])=(a[t+1],a[s+1])
            s=s+1
    # mover pivote al centro
    (a[i],a[s])=(a[s],a[i])
    return s

# %%
def chequea_orden(a):
    print("Ordenado" if np.all(a[:-1]<=a[1:]) else "Desordenado")

# %%
import numpy as np
a = np.random.random(30)
print(a)
chequea_orden(a)
quicksort(a)
print(a)
chequea_orden(a)
# Out:
# [0.83363956 0.73119243 0.00178298 0.02869565 0.05722011 0.55263889
#  0.56425412 0.02047658 0.85035471 0.8981872  0.66269982 0.10589184
#  0.1367046  0.59367435 0.88653386 0.76389336 0.97329859 0.19915611
#  0.10677626 0.59069712 0.15754067 0.54135669 0.45042508 0.14124281
#  0.22281095 0.17438681 0.35119782 0.18881143 0.68099943 0.88675805]
# Desordenado
# [0.00178298 0.02047658 0.02869565 0.05722011 0.10589184 0.10677626
#  0.1367046  0.14124281 0.15754067 0.17438681 0.18881143 0.19915611
#  0.22281095 0.35119782 0.45042508 0.54135669 0.55263889 0.56425412
#  0.59069712 0.59367435 0.66269982 0.68099943 0.73119243 0.76389336
#  0.83363956 0.85035471 0.88653386 0.88675805 0.8981872  0.97329859]
# Ordenado

# %% [markdown]
# # La tarea: Quicksort con mediana de tres
#
# Usted debe programar una partición que determine el pivote como la mediana de tres elementos escogido entre el primer, el del medio y el último del segmento a particionar. Para esto, debe modificar el algoritmo de partición de modo que  re-ordene estos 3 elementos dejando en $a[i]$ el mínimo de los 3, en $a[i+1]$ la mediana de los 3 y en $a[j]$ el máximo de los 3. Luego, se aplica el algoritmo de partición ya conocido al segmento $a[i+2],\ldots,a[j-1]$, con $a[i+1]$ como pivote. Al terminar, el pivote se mueve al centro y se retorna su posición.
#
# Otro cambio que se debe hacer es tratar los casos de arreglos de tamaño $0$, $1$ y $2$ como casos de borde, y aplicar ``qsort`` recursivo solo a arreglos de tamaño mayor o igual a 3.
#
# En el siguiente recuadro escriba su algoritmo modificado y luego ejecute las instrucciones de prueba del recuadro siguiente.

# %%
#version encontrando 3 elementos al azar
import random
def quicksort3(a):
  qsort3(a,0,len(a)-1)

def qsort3(a,i,j): # ordena a[i],...,a[j]
  if len(a) == 0:
    # dado que el arreglo es de tamaño 0, ya se encuentra ordenado
    pass
  elif len(a) == 1:
    # dado que el arreglo es de tamaño 1, ya se encuentra ordenado
    pass
  elif len(a) == 2:
    if a[0]>a[1]:
      (a[0],a[1])=(a[1],a[0])
  else:
    if i<j: # quedan 2 o más elementos por ordenar
        k=particionMedianaDe3(a,i,j)
        qsort3(a,i,k-1)
        qsort3(a,k+1,j)

  # aquí debería dividir para tomar en cuenta los casos borde: arreglos de tamaño 0,1,2
  # aplicar qsort recursivo solo a arreglos de tamaño mayor o igual a 3

#Implementar esta función de acuerdo al enunciado
def particionMedianaDe3(a,i,j): # particiona a[i],...,a[j], retorna posición del pivote
  m = min(a[i],a[(j+i)//2],a[j])
  if m == a[i]:
    if a[(j+i)//2]>a[j]:
      medio = a[j]
      mayor = a[(j+i)//2]
    else:
      medio = a[(j+i)//2]
      mayor = a[j]
  elif m == a[(j+i)//2]:
    if a[i]>a[j]:
      medio = a[j]
      mayor = a[i]
    else:
      medio = a[i]
      mayor = a[j]
  else: # m == a[j]
    if a[i]>a[(j+i)//2]:
      medio = a[(j+i)//2]
      mayor = a[i]
    else:
      medio = a[i]
      mayor = a[(j+i)//2]
  a[i] = m
  a[j] = mayor
  a[i+1] = medio
  # ahora, uso a[i+1] como pivote

  # a[i+1] es el pivote
  s=i+1 # invariante: a[i+2..s]<=a[i+1], a[s+1..t]>a[i+1]
  global contador_qs3
  for t in range(s,j):
      contador_qs3 +=1
      if a[t+1]<=a[i+1]:
          (a[s+1],a[t+1])=(a[t+1],a[s+1])
          s=s+1
  # mover pivote al centro
  (a[i+1],a[s])=(a[s],a[i+1])
  return s

# Luego, se aplica el algoritmo de partición ya conocido al segmento  a[i+2],…,a[j−1] ,
#con  a[i+1]  como pivote.
# Al terminar, el pivote se mueve al centro y se retorna su posición.

# %%
import numpy as np
a = np.random.random(30)
print(a)
chequea_orden(a)
quicksort3(a)
print(a)
chequea_orden(a)
# Out:
# [0.4601646  0.44407926 0.50039777 0.39898932 0.27848487 0.52743476
#  0.75811839 0.65887218 0.61672826 0.86106978 0.61921006 0.98335518
#  0.01518637 0.37593136 0.33469293 0.3812182  0.30652856 0.39801396
#  0.47175967 0.3210195  0.36996678 0.144937   0.84436477 0.17490936
#  0.99291483 0.66959094 0.91697985 0.44934769 0.08189472 0.25702639]
# Desordenado
# [0.01518637 0.144937   0.17490936 0.25702639 0.27848487 0.27848487
#  0.3210195  0.33469293 0.33469293 0.33469293 0.37593136 0.37593136
#  0.3812182  0.39801396 0.39898932 0.39898932 0.4601646  0.47175967
#  0.50039777 0.52743476 0.52743476 0.61921006 0.65887218 0.65887218
#  0.66959094 0.75811839 0.84436477 0.84436477 0.91697985 0.99291483]
# Ordenado

# %% [markdown]
# Una vez programada la variante quicksort con mediana de tres, se le pide que mida el tiempo promedio que ambas versiones demoran en ordenar y cuente además el número promedio de comparaciones que se hacen dentro de la función de partición para las dos versiones operando sobre el mismo arreglo. Para eso debe crear arreglos con elementos generados al azar (use `np.random.random(n)`, donde `n` es el número de elementos), hacer una copia de él y ordenar uno con el método quicksort original y el otro con el método de mediana de tres, registrando el tiempo que demora cada ordenamiento y la cantidad de comparaciones. Este proceso debe ejecutarlo 15 veces y sacar el promedio del tiempo y de comparaciones para cada versión para un `n` fijo.
#
# Repita el procedimiento para `n` = 100, 500, 1000, 5000, 10000, 20000 y 40000, completando así una tabla similar a la que se ve a continuación.
#
# ![e7da1921-2239-4f3c-98b4-b85b15dcfdae.png](data:image/png;base64,...)

# %% [markdown]
# Una vez completada la tabla grafique sus resultados (de la forma que estime más conveniente presentarlos) e incluya el gráfico al final de  este documento. Para tomar el tiempo que demora un proceso puede usar la función `time.gettime_ns(0)` que registra el tiempo actual en nanosegundos que han pasado desde el 1/1/1970 00:00 horas. Puede usarlo de la siguiente manera:

# %%
import time
contador_qs = 0
contador_qs3 = 0
a = np.random.random(100)
t1 = time.clock_gettime_ns(0)
quicksort3(a)
comparacion = contador_qs
comp2 = contador_qs3
t2 = time.clock_gettime_ns(0)
print("el tiempo que demoró el proceso fue de ",(t2-t1),"nanosegundos")
print(str(comparacion),str(comp2))
# Out:
# el tiempo que demoró el proceso fue de  851724 nanosegundos
# 0 560

# %% [markdown]
# Para contar las comparaciones puede usar variables globales que se incrementan convenientemente. Solo cuente las comparaciones que se hacen en el proceso de partición (dentro del `for`). Tenga sumo cuidado de asegurarse que cada vez que se corra el experimento (ordenamiento del arreglo generado al azar por los dos métodos) estos reciban una copia del arreglo original desordenado y no una referencia al arreglo que ya fue ordenado en una instancia anterior. Programe las instrucciones que ejecuten el experimento descrito anteriormente, en el siguiente recuadro:

# %%
import numpy as np
import time
from statistics import mean
ns = [100,1000, 5000, 10000, 15000, 20000, 40000]

# %%
def tiempo(metodo,lista_tiempos,prueba_):
  t1 = time.clock_gettime_ns(0)
  metodo(prueba_)
  t2 = time.clock_gettime_ns(0)
  if metodo == quicksort:
    print("el tiempo que demoró el proceso quicksort fue de ",(t2-t1),"nanosegundos")
  elif metodo == quicksort3:
    print("el tiempo que demoró el proceso quicksort3 fue de ",(t2-t1),"nanosegundos")
  lista_tiempos.append(t2-t1)

# %%
for numero in ns:
  tiempos_qs = list()
  tiempos_qs3 = list()
  listcont_qs = list()
  listcont_qs3 = list()
  for i in range(15):
    contador_qs = 0
    contador_qs3 = 0
    prueba = np.random.random(numero)
    prueba_copy = prueba.copy()
    tiempo(quicksort,tiempos_qs,prueba)
    tiempo(quicksort3,tiempos_qs3,prueba_copy)
    print("La cantidad de comparaciones para el método quicksort fue de " + str(contador_qs))
    listcont_qs.append(contador_qs)
    print("La cantidad de comparaciones para el método quicksort3 fue de " + str(contador_qs3))
    listcont_qs3.append(contador_qs3)

  print(tiempos_qs)
  print(tiempos_qs3)
  print(listcont_qs)
  print(listcont_qs3)

  promedio_qs = mean(tiempos_qs)
  promedio_qs3 = mean(tiempos_qs3)
  promcont_qs = mean(listcont_qs)
  promcont_qs3 = mean(listcont_qs3)

  print("El promedio de tiempo para n = " + str(numero) + " para el método quicksort es " + str(promedio_qs))
  print("El promedio de tiempo para n = " + str(numero) + " para el método quicksort3 es " + str(promedio_qs3))
  print("El promedio de comparaciones para n = " + str(numero) + " para el método quicksort es " + str(promcont_qs))
  print("El promedio de comparaciones para n = " + str(numero) + " para el método quicksort3 es " + str(promcont_qs3))
# Out:
# el tiempo que demoró el proceso quicksort fue de  479952 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  488162 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 630
# La cantidad de comparaciones para el método quicksort3 fue de 456
# el tiempo que demoró el proceso quicksort fue de  499602 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  526202 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 740
# La cantidad de comparaciones para el método quicksort3 fue de 492
# el tiempo que demoró el proceso quicksort fue de  540732 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  575932 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 691
# La cantidad de comparaciones para el método quicksort3 fue de 537
# el tiempo que demoró el proceso quicksort fue de  228451 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  319601 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 600
# La cantidad de comparaciones para el método quicksort3 fue de 449
# el tiempo que demoró el proceso quicksort fue de  237401 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  333532 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 631
# La cantidad de comparaciones para el método quicksort3 fue de 485
# el tiempo que demoró el proceso quicksort fue de  330362 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  310451 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 615
# La cantidad de comparaciones para el método quicksort3 fue de 475
# el tiempo que demoró el proceso quicksort fue de  454712 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  506362 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 581
# La cantidad de comparaciones para el método quicksort3 fue de 473
# el tiempo que demoró el proceso quicksort fue de  422452 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  427352 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 651
# La cantidad de comparaciones para el método quicksort3 fue de 478
# el tiempo que demoró el proceso quicksort fue de  453442 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  459582 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 660
# La cantidad de comparaciones para el método quicksort3 fue de 477
# el tiempo que demoró el proceso quicksort fue de  451712 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  545072 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 647
# La cantidad de comparaciones para el método quicksort3 fue de 499
# el tiempo que demoró el proceso quicksort fue de  437942 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  470322 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 634
# La cantidad de comparaciones para el método quicksort3 fue de 494
# el tiempo que demoró el proceso quicksort fue de  432602 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  485053 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 604
# La cantidad de comparaciones para el método quicksort3 fue de 486
# el tiempo que demoró el proceso quicksort fue de  488642 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  534152 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 682
# La cantidad de comparaciones para el método quicksort3 fue de 490
# el tiempo que demoró el proceso quicksort fue de  450342 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  770514 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 589
# La cantidad de comparaciones para el método quicksort3 fue de 486
# el tiempo que demoró el proceso quicksort fue de  538322 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  463862 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 808
# La cantidad de comparaciones para el método quicksort3 fue de 451
# [479952, 499602, 540732, 228451, 237401, 330362, 454712, 422452, 453442, 451712, 437942, 432602, 488642, 450342, 538322]
# [488162, 526202, 575932, 319601, 333532, 310451, 506362, 427352, 459582, 545072, 470322, 485053, 534152, 770514, 463862]
# [630, 740, 691, 600, 631, 615, 581, 651, 660, 647, 634, 604, 682, 589, 808]
# [456, 492, 537, 449, 485, 475, 473, 478, 477, 499, 494, 486, 490, 486, 451]
# El promedio de tiempo para n = 100 para el método quicksort es 429777.86666666664
# El promedio de tiempo para n = 100 para el método quicksort3 es 481076.73333333334
# El promedio de comparaciones para n = 100 para el método quicksort es 650.8666666666667
# El promedio de comparaciones para n = 100 para el método quicksort3 es 481.8666666666667
# el tiempo que demoró el proceso quicksort fue de  17070336 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  8700599 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 10591
# La cantidad de comparaciones para el método quicksort3 fue de 9061
# el tiempo que demoró el proceso quicksort fue de  8536327 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  14097642 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 11365
# La cantidad de comparaciones para el método quicksort3 fue de 8963
# el tiempo que demoró el proceso quicksort fue de  9006021 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  9289351 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 11488
# La cantidad de comparaciones para el método quicksort3 fue de 9468
# el tiempo que demoró el proceso quicksort fue de  7393223 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  8211566 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 10053
# La cantidad de comparaciones para el método quicksort3 fue de 9148
# el tiempo que demoró el proceso quicksort fue de  8395487 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  8105216 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 11780
# La cantidad de comparaciones para el método quicksort3 fue de 8947
# el tiempo que demoró el proceso quicksort fue de  9208501 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  7913175 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 12282
# La cantidad de comparaciones para el método quicksort3 fue de 8441
# el tiempo que demoró el proceso quicksort fue de  9736113 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  6691279 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 12649
# La cantidad de comparaciones para el método quicksort3 fue de 8679
# el tiempo que demoró el proceso quicksort fue de  4272929 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  4079018 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 11328
# La cantidad de comparaciones para el método quicksort3 fue de 8457
# el tiempo que demoró el proceso quicksort fue de  4647321 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  4140948 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 12649
# La cantidad de comparaciones para el método quicksort3 fue de 8850
# el tiempo que demoró el proceso quicksort fue de  3890257 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  4140819 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 10964
# La cantidad de comparaciones para el método quicksort3 fue de 8831
# el tiempo que demoró el proceso quicksort fue de  3889847 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  3890827 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 10519
# La cantidad de comparaciones para el método quicksort3 fue de 8589
# el tiempo que demoró el proceso quicksort fue de  3957167 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  4034207 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 10957
# La cantidad de comparaciones para el método quicksort3 fue de 8563
# el tiempo que demoró el proceso quicksort fue de  4937362 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  4193168 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 11579
# La cantidad de comparaciones para el método quicksort3 fue de 8584
# el tiempo que demoró el proceso quicksort fue de  3862887 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  4099869 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 10276
# La cantidad de comparaciones para el método quicksort3 fue de 8365
# el tiempo que demoró el proceso quicksort fue de  4306019 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  4226698 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 11287
# La cantidad de comparaciones para el método quicksort3 fue de 8654
# [17070336, 8536327, 9006021, 7393223, 8395487, 9208501, 9736113, 4272929, 4647321, 3890257, 3889847, 3957167, 4937362, 3862887, 4306019]
# [8700599, 14097642, 9289351, 8211566, 8105216, 7913175, 6691279, 4079018, 4140948, 4140819, 3890827, 4034207, 4193168, 4099869, 4226698]
# [10591, 11365, 11488, 10053, 11780, 12282, 12649, 11328, 12649, 10964, 10519, 10957, 11579, 10276, 11287]
# [9061, 8963, 9468, 9148, 8947, 8441, 8679, 8457, 8850, 8831, 8589, 8563, 8584, 8365, 8654]
# El promedio de tiempo para n = 1000 para el método quicksort es 6873986.466666667
# El promedio de tiempo para n = 1000 para el método quicksort3 es 6387625.466666667
# El promedio de comparaciones para n = 1000 para el método quicksort es 11317.8
# El promedio de comparaciones para n = 1000 para el método quicksort3 es 8773.333333333334
# el tiempo que demoró el proceso quicksort fue de  32103802 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  29409470 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 69798
# La cantidad de comparaciones para el método quicksort3 fue de 56028
# el tiempo que demoró el proceso quicksort fue de  24967331 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  27482062 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 67338
# La cantidad de comparaciones para el método quicksort3 fue de 56319
# el tiempo que demoró el proceso quicksort fue de  26370287 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  26695718 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 67382
# La cantidad de comparaciones para el método quicksort3 fue de 55359
# el tiempo que demoró el proceso quicksort fue de  24747690 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  29960603 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 68491
# La cantidad de comparaciones para el método quicksort3 fue de 57986
# el tiempo que demoró el proceso quicksort fue de  27868113 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  30950337 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 71907
# La cantidad de comparaciones para el método quicksort3 fue de 59425
# el tiempo que demoró el proceso quicksort fue de  25760643 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  31313099 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 72457
# La cantidad de comparaciones para el método quicksort3 fue de 58043
# el tiempo que demoró el proceso quicksort fue de  24536779 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  34577153 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 70440
# La cantidad de comparaciones para el método quicksort3 fue de 60160
# el tiempo que demoró el proceso quicksort fue de  31655040 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  33219137 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 75313
# La cantidad de comparaciones para el método quicksort3 fue de 59343
# el tiempo que demoró el proceso quicksort fue de  27558132 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  30609556 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 67974
# La cantidad de comparaciones para el método quicksort3 fue de 55133
# el tiempo que demoró el proceso quicksort fue de  42343897 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  33424288 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 80576
# La cantidad de comparaciones para el método quicksort3 fue de 57229
# el tiempo que demoró el proceso quicksort fue de  25390182 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  28537116 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 69135
# La cantidad de comparaciones para el método quicksort3 fue de 56783
# el tiempo que demoró el proceso quicksort fue de  30111154 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  29677321 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 75300
# La cantidad de comparaciones para el método quicksort3 fue de 56184
# el tiempo que demoró el proceso quicksort fue de  27945744 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  27416702 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 72652
# La cantidad de comparaciones para el método quicksort3 fue de 57509
# el tiempo que demoró el proceso quicksort fue de  29349460 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  28645407 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 71299
# La cantidad de comparaciones para el método quicksort3 fue de 60639
# el tiempo que demoró el proceso quicksort fue de  27015630 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  31589850 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 70140
# La cantidad de comparaciones para el método quicksort3 fue de 58535
# [32103802, 24967331, 26370287, 24747690, 27868113, 25760643, 24536779, 31655040, 27558132, 42343897, 25390182, 30111154, 27945744, 29349460, 27015630]
# [29409470, 27482062, 26695718, 29960603, 30950337, 31313099, 34577153, 33219137, 30609556, 33424288, 28537116, 29677321, 27416702, 28645407, 31589850]
# [69798, 67338, 67382, 68491, 71907, 72457, 70440, 75313, 67974, 80576, 69135, 75300, 72652, 71299, 70140]
# [56028, 56319, 55359, 57986, 59425, 58043, 60160, 59343, 55133, 57229, 56783, 56184, 57509, 60639, 58535]
# El promedio de tiempo para n = 5000 para el método quicksort es 28514925.6
# El promedio de tiempo para n = 5000 para el método quicksort3 es 30233854.6
# El promedio de comparaciones para n = 5000 para el método quicksort es 71346.8
# El promedio de comparaciones para n = 5000 para el método quicksort3 es 57645
# el tiempo que demoró el proceso quicksort fue de  62422306 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  57999726 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 157123
# La cantidad de comparaciones para el método quicksort3 fue de 122391
# el tiempo que demoró el proceso quicksort fue de  54157460 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  61232010 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 152638
# La cantidad de comparaciones para el método quicksort3 fue de 126847
# el tiempo que demoró el proceso quicksort fue de  61098430 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  73775757 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 156256
# La cantidad de comparaciones para el método quicksort3 fue de 122208
# el tiempo que demoró el proceso quicksort fue de  61341991 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  64647446 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 155225
# La cantidad de comparaciones para el método quicksort3 fue de 137498
# el tiempo que demoró el proceso quicksort fue de  62704297 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  62325196 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 176190
# La cantidad de comparaciones para el método quicksort3 fue de 131153
# el tiempo que demoró el proceso quicksort fue de  62681527 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  64156064 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 161217
# La cantidad de comparaciones para el método quicksort3 fue de 127201
# el tiempo que demoró el proceso quicksort fue de  58860491 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  62284435 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 166035
# La cantidad de comparaciones para el método quicksort3 fue de 131768
# el tiempo que demoró el proceso quicksort fue de  53761167 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  61562612 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 152799
# La cantidad de comparaciones para el método quicksort3 fue de 124731
# el tiempo que demoró el proceso quicksort fue de  58079147 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  62743128 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 161898
# La cantidad de comparaciones para el método quicksort3 fue de 128712
# el tiempo que demoró el proceso quicksort fue de  57102573 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  57257993 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 161059
# La cantidad de comparaciones para el método quicksort3 fue de 122067
# el tiempo que demoró el proceso quicksort fue de  63566041 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  62078664 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 156575
# La cantidad de comparaciones para el método quicksort3 fue de 125696
# el tiempo que demoró el proceso quicksort fue de  60973040 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  68051511 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 160229
# La cantidad de comparaciones para el método quicksort3 fue de 128285
# el tiempo que demoró el proceso quicksort fue de  61536422 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  69461107 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 154517
# La cantidad de comparaciones para el método quicksort3 fue de 126814
# el tiempo que demoró el proceso quicksort fue de  131783453 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  112008195 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 166106
# La cantidad de comparaciones para el método quicksort3 fue de 129134
# el tiempo que demoró el proceso quicksort fue de  57284074 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  60965210 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 150940
# La cantidad de comparaciones para el método quicksort3 fue de 121032
# [62422306, 54157460, 61098430, 61341991, 62704297, 62681527, 58860491, 53761167, 58079147, 57102573, 63566041, 60973040, 61536422, 131783453, 57284074]
# [57999726, 61232010, 73775757, 64647446, 62325196, 64156064, 62284435, 61562612, 62743128, 57257993, 62078664, 68051511, 69461107, 112008195, 60965210]
# [157123, 152638, 156256, 155225, 176190, 161217, 166035, 152799, 161898, 161059, 156575, 160229, 154517, 166106, 150940]
# [122391, 126847, 122208, 137498, 131153, 127201, 131768, 124731, 128712, 122067, 125696, 128285, 126814, 129134, 121032]
# El promedio de tiempo para n = 10000 para el método quicksort es 64490161.266666666
# El promedio de tiempo para n = 10000 para el método quicksort3 es 66703270.266666666
# El promedio de comparaciones para n = 10000 para el método quicksort es 159253.8
# El promedio de comparaciones para n = 10000 para el método quicksort3 es 127035.8
# el tiempo que demoró el proceso quicksort fue de  95915474 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  91362954 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 238723
# La cantidad de comparaciones para el método quicksort3 fue de 197976
# el tiempo que demoró el proceso quicksort fue de  104658243 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  102430542 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 272010
# La cantidad de comparaciones para el método quicksort3 fue de 212879
# el tiempo que demoró el proceso quicksort fue de  87199145 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  94849210 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 234100
# La cantidad de comparaciones para el método quicksort3 fue de 192936
# el tiempo que demoró el proceso quicksort fue de  166098924 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  166504486 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 269967
# La cantidad de comparaciones para el método quicksort3 fue de 204614
# el tiempo que demoró el proceso quicksort fue de  177651076 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  173696868 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 252262
# La cantidad de comparaciones para el método quicksort3 fue de 193975
# el tiempo que demoró el proceso quicksort fue de  168119653 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  173616158 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 239699
# La cantidad de comparaciones para el método quicksort3 fue de 194393
# el tiempo que demoró el proceso quicksort fue de  204916606 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  164163146 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 269016
# La cantidad de comparaciones para el método quicksort3 fue de 196049
# el tiempo que demoró el proceso quicksort fue de  176712261 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  167612911 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 245828
# La cantidad de comparaciones para el método quicksort3 fue de 198395
# el tiempo que demoró el proceso quicksort fue de  174236611 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  122883363 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 242401
# La cantidad de comparaciones para el método quicksort3 fue de 206268
# el tiempo que demoró el proceso quicksort fue de  88673212 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  101028436 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 240414
# La cantidad de comparaciones para el método quicksort3 fue de 198166
# el tiempo que demoró el proceso quicksort fue de  87188115 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  90525260 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 239489
# La cantidad de comparaciones para el método quicksort3 fue de 198740
# el tiempo que demoró el proceso quicksort fue de  94065346 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  98460986 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 246581
# La cantidad de comparaciones para el método quicksort3 fue de 211189
# el tiempo que demoró el proceso quicksort fue de  98330145 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  92434359 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 251327
# La cantidad de comparaciones para el método quicksort3 fue de 195925
# el tiempo que demoró el proceso quicksort fue de  167624141 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  149584622 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 250231
# La cantidad de comparaciones para el método quicksort3 fue de 194679
# el tiempo que demoró el proceso quicksort fue de  212335289 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  199766283 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 239041
# La cantidad de comparaciones para el método quicksort3 fue de 199202
# [95915474, 104658243, 87199145, 166098924, 177651076, 168119653, 204916606, 176712261, 174236611, 88673212, 87188115, 94065346, 98330145, 167624141, 212335289]
# [91362954, 102430542, 94849210, 166504486, 173696868, 173616158, 164163146, 167612911, 122883363, 101028436, 90525260, 98460986, 92434359, 149584622, 199766283]
# [238723, 272010, 234100, 269967, 252262, 239699, 269016, 245828, 242401, 240414, 239489, 246581, 251327, 250231, 239041]
# [197976, 212879, 192936, 204614, 193975, 194393, 196049, 198395, 206268, 198166, 198740, 211189, 195925, 194679, 199202]
# El promedio de tiempo para n = 15000 para el método quicksort es 140248282.73333332
# El promedio de tiempo para n = 15000 para el método quicksort3 es 132594638.93333334
# El promedio de comparaciones para n = 15000 para el método quicksort es 248739.26666666666
# El promedio de comparaciones para n = 15000 para el método quicksort3 es 199692.4
# el tiempo que demoró el proceso quicksort fue de  285574982 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  243279385 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 347215
# La cantidad de comparaciones para el método quicksort3 fue de 273166
# el tiempo que demoró el proceso quicksort fue de  262145509 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  281849156 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 336519
# La cantidad de comparaciones para el método quicksort3 fue de 270277
# el tiempo que demoró el proceso quicksort fue de  369113671 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  311910678 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 356441
# La cantidad de comparaciones para el método quicksort3 fue de 278975
# el tiempo que demoró el proceso quicksort fue de  329181734 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  277853598 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 328578
# La cantidad de comparaciones para el método quicksort3 fue de 274235
# el tiempo que demoró el proceso quicksort fue de  432974823 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  320685607 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 352269
# La cantidad de comparaciones para el método quicksort3 fue de 280666
# el tiempo que demoró el proceso quicksort fue de  342640054 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  402903321 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 336081
# La cantidad de comparaciones para el método quicksort3 fue de 277087
# el tiempo que demoró el proceso quicksort fue de  342066122 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  344443203 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 353044
# La cantidad de comparaciones para el método quicksort3 fue de 280338
# el tiempo que demoró el proceso quicksort fue de  542963989 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  294881124 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 350249
# La cantidad de comparaciones para el método quicksort3 fue de 276781
# el tiempo que demoró el proceso quicksort fue de  302370735 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  252843721 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 335908
# La cantidad de comparaciones para el método quicksort3 fue de 280766
# el tiempo que demoró el proceso quicksort fue de  353308014 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  359160664 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 329509
# La cantidad de comparaciones para el método quicksort3 fue de 273728
# el tiempo que demoró el proceso quicksort fue de  127914275 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  132215278 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 332553
# La cantidad de comparaciones para el método quicksort3 fue de 272211
# el tiempo que demoró el proceso quicksort fue de  129009784 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  122872652 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 323610
# La cantidad de comparaciones para el método quicksort3 fue de 265796
# el tiempo que demoró el proceso quicksort fue de  126901993 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  134395008 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 320194
# La cantidad de comparaciones para el método quicksort3 fue de 282870
# el tiempo que demoró el proceso quicksort fue de  133630760 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  126079165 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 360463
# La cantidad de comparaciones para el método quicksort3 fue de 280304
# el tiempo que demoró el proceso quicksort fue de  131599414 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  134065937 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 326848
# La cantidad de comparaciones para el método quicksort3 fue de 274659
# [285574982, 262145509, 369113671, 329181734, 432974823, 342640054, 342066122, 542963989, 302370735, 353308014, 127914275, 129009784, 126901993, 133630760, 131599414]
# [243279385, 281849156, 311910678, 277853598, 320685607, 402903321, 344443203, 294881124, 252843721, 359160664, 132215278, 122872652, 134395008, 126079165, 134065937]
# [347215, 336519, 356441, 328578, 352269, 336081, 353044, 350249, 335908, 329509, 332553, 323610, 320194, 360463, 326848]
# [273166, 270277, 278975, 274235, 280666, 277087, 280338, 276781, 280766, 273728, 272211, 265796, 282870, 280304, 274659]
# El promedio de tiempo para n = 20000 para el método quicksort es 280759723.93333334
# El promedio de tiempo para n = 20000 para el método quicksort3 es 249295899.8
# El promedio de comparaciones para n = 20000 para el método quicksort es 339298.73333333334
# El promedio de comparaciones para n = 20000 para el método quicksort3 es 276123.93333333335
# el tiempo que demoró el proceso quicksort fue de  268506824 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  379241797 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 711068
# La cantidad de comparaciones para el método quicksort3 fue de 598715
# el tiempo que demoró el proceso quicksort fue de  534557095 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  514725516 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 769329
# La cantidad de comparaciones para el método quicksort3 fue de 615797
# el tiempo que demoró el proceso quicksort fue de  548468206 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  367547496 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 736297
# La cantidad de comparaciones para el método quicksort3 fue de 609292
# el tiempo que demoró el proceso quicksort fue de  279399838 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  276795568 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 727059
# La cantidad de comparaciones para el método quicksort3 fue de 595715
# el tiempo que demoró el proceso quicksort fue de  283298281 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  281931859 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 713808
# La cantidad de comparaciones para el método quicksort3 fue de 610936
# el tiempo que demoró el proceso quicksort fue de  277742172 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  270469121 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 748336
# La cantidad de comparaciones para el método quicksort3 fue de 613551
# el tiempo que demoró el proceso quicksort fue de  264595311 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  278292367 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 725341
# La cantidad de comparaciones para el método quicksort3 fue de 595272
# el tiempo que demoró el proceso quicksort fue de  274912270 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  282047256 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 709088
# La cantidad de comparaciones para el método quicksort3 fue de 606853
# el tiempo que demoró el proceso quicksort fue de  266264215 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  264465465 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 712669
# La cantidad de comparaciones para el método quicksort3 fue de 587214
# el tiempo que demoró el proceso quicksort fue de  283488636 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  270647465 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 731310
# La cantidad de comparaciones para el método quicksort3 fue de 597064
# el tiempo que demoró el proceso quicksort fue de  276137186 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  272222263 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 759539
# La cantidad de comparaciones para el método quicksort3 fue de 604277
# el tiempo que demoró el proceso quicksort fue de  290099297 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  273176247 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 747512
# La cantidad de comparaciones para el método quicksort3 fue de 592274
# el tiempo que demoró el proceso quicksort fue de  262055579 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  272920494 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 696465
# La cantidad de comparaciones para el método quicksort3 fue de 606018
# el tiempo que demoró el proceso quicksort fue de  281088472 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  274462362 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 732023
# La cantidad de comparaciones para el método quicksort3 fue de 616476
# el tiempo que demoró el proceso quicksort fue de  254317961 nanosegundos
# el tiempo que demoró el proceso quicksort3 fue de  276612483 nanosegundos
# La cantidad de comparaciones para el método quicksort fue de 692751
# La cantidad de comparaciones para el método quicksort3 fue de 588383
# [268506824, 534557095, 548468206, 279399838, 283298281, 277742172, 264595311, 274912270, 266264215, 283488636, 276137186, 290099297, 262055579, 281088472, 254317961]
# [379241797, 514725516, 367547496, 276795568, 281931859, 270469121, 278292367, 282047256, 264465465, 270647465, 272222263, 273176247, 272920494, 274462362, 276612483]
# [711068, 769329, 736297, 727059, 713808, 748336, 725341, 709088, 712669, 731310, 759539, 747512, 696465, 732023, 692751]
# [598715, 615797, 609292, 595715, 610936, 613551, 595272, 606853, 587214, 597064, 604277, 592274, 606018, 616476, 588383]
# El promedio de tiempo para n = 40000 para el método quicksort es 309662089.53333336
# El promedio de tiempo para n = 40000 para el método quicksort3 es 303703850.6
# El promedio de comparaciones para n = 40000 para el método quicksort es 727506.3333333334
# El promedio de comparaciones para n = 40000 para el método quicksort3 es 602522.4666666667

# %% [markdown]
# Primero haremos la tabla comparativa entre el número de iteraciones asociado tanto a la parte 1 como la parte 2
#
# | Valores de N | Quicksort |  | Quicksort3 |  |
# | --- | --- | --- | --- | --- |
# |  | Tiempo (ns) | N° de comparaciones | Tiempo (ns) | N° de comparaciones |
# | 100 | 502452.7 | 673 | 505664.5 |479 |
# | 1000 | 7248865.4 | 10967 | 7942577.1 |8710 |
# | 5000 | 44270420.3 | 70239 | 45704792.0 |57519 |
# | 10000 | 95455906.6 | 158730 | 99436226 |126286 |
# | 15000 | 207874947.8 | 246165 | 197435128.8 |199300 |
# | 20000 | 203092566.6 | 332401 | 209149466.1 |277975 |
# | 40000 | 473051005.9 | 725534 | 506199074.7 |603559 |

# %%
#Para hacer el gráfico comparativo usaremos matplotlib
# N° de comparaciones

import matplotlib.pyplot as plt
fig, ax = plt.subplots()
#Quicksort
plt.plot([100, 1000, 5000, 10000, 15000, 20000, 40000], [673, 10967, 70239, 158730, 246165, 332401, 725534], color="g", label="Quicksort")
#Quicksort3
plt.plot([100, 1000, 5000, 10000, 15000, 20000, 40000], [479, 8710, 57519, 126286, 199300, 277975, 603559], color="m", label="Quicksort3")
plt.title("Gráfico comparativo de número de comparaciones")
plt.xlabel("Valor de N")
plt.ylabel("N° de comparaciones")
plt.legend()
plt.show()

#Es posible concluir que el método quicksort3 usa menos comparaciones en promedio que el quicksort original

# %%
# Tiempo(ns)

import matplotlib.pyplot as plt
fig, ax = plt.subplots()
#Quicksort
plt.plot([100, 1000, 5000, 10000, 15000, 20000, 40000], [502452.7, 7248865.4, 44270420.3, 95455906.6, 207874947.8, 203092566.6, 473051005.9], color="g", label="Quicksort")
#Quicksort3
plt.plot([100, 1000, 5000, 10000, 15000, 20000, 40000], [505664.5, 7942577.1, 45704792.0, 99436226, 197435128.8, 209149466.1, 506199074.7], color="m", label="Quicksort3")
plt.title("Gráfico comparativo de tiempos de ejecución")
plt.xlabel("Valor de N")
plt.ylabel("Tiempo (ns)")
plt.legend()
plt.show()

#Es posible concluir que el método quicksort3 se tarda un poco más que el quicksort original.
#Una posible razón para esto es el uso de la función "min"
